# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
# seperated by a tab
data = np.loadtxt('data.txt', delimiter='\t')   
x = data[:, 0]
y = data[:, 1]
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('x^2')
plt.title('Data from arduino loop')
plt.grid(True)

plt.show()
